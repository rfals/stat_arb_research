# %% [markdown]
# # First Look at the Data

# %%
import os
import zipfile

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet(r"C:\Users\ReinisFals\OneDrive - Peero, SIA\Desktop\stat_arb_research\stat_arb_research\data\A_MERGEABLE\AAVE\AAVEUSDT-1m-2020-10.parquet")
df
# Out:
#        1602730800000  51.43000000  59.00000000  50.66600000  55.60700000  \
# 0      1602730860000       55.603       55.623       52.000       52.845
# 1      1602730920000       52.845       52.846       51.283       51.999
# 2      1602730980000       51.999       52.000       50.665       51.736
# 3      1602731040000       51.742       51.776       51.500       51.632
# 4      1602731100000       51.641       51.737       51.579       51.640
# ...              ...          ...          ...          ...          ...
# 24294  1604188500000       29.754       29.754       29.754       29.754
# 24295  1604188560000       29.754       29.754       29.754       29.754
# 24296  1604188620000       29.700       29.700       29.700       29.700
# 24297  1604188680000       29.700       29.700       29.700       29.700
# 24298  1604188740000       29.700       29.700       29.700       29.700
#
#        1369.48100000  1602730859999  75607.77901300  361  898.43400000  \
# ...

# %%
df2 = pd.read_parquet(r"C:\Users\ReinisFals\OneDrive - Peero, SIA\Desktop\stat_arb_research\stat_arb_research\data\A_MERGEABLE\AAVE\AAVEUSDT-1m-2020-10.parquet")
df2
# Out:
#        1602730800000  51.43000000  59.00000000  50.66600000  55.60700000  \
# 0      1602730860000       55.603       55.623       52.000       52.845
# 1      1602730920000       52.845       52.846       51.283       51.999
# 2      1602730980000       51.999       52.000       50.665       51.736
# 3      1602731040000       51.742       51.776       51.500       51.632
# 4      1602731100000       51.641       51.737       51.579       51.640
# ...              ...          ...          ...          ...          ...
# 24294  1604188500000       29.754       29.754       29.754       29.754
# 24295  1604188560000       29.754       29.754       29.754       29.754
# 24296  1604188620000       29.700       29.700       29.700       29.700
# 24297  1604188680000       29.700       29.700       29.700       29.700
# 24298  1604188740000       29.700       29.700       29.700       29.700
#
#        1369.48100000  1602730859999  75607.77901300  361  898.43400000  \
# ...

# %% [markdown]
# ## Column Names
#
#  - **open_time**: The time the bar opened
#  - **open**: The price the bar opened at
#  - **high**: The highest price the bar reached
#  - **low**: The lowest price the bar reached
#  - **close**: The price the bar closed at
#  - **volume**: The volume of the bar
#  - **close_time**: The time the bar closed
#  - **quote_asset_volume**: The volume of the bar in the quote asset
#  - **count**: The number of trades in the bar
#  - **taker_buy_base_asset_volume**: The volume of the asset bought by takers
#  - **taker_buy_quote_asset_volume**: The volume of the quote asset bought by takers
#  - **ignore**: Ignore this column

# %%
# open_time, open, high, low, close, volume, close_time, quote_asset_volume, count, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore

# %% [markdown]
# ## Desired Data Format

# %%
df_desired = pd.read_parquet(r"C:\Users\ReinisFals\OneDrive - Peero, SIA\Desktop\Statistical_Arbitrage\binance_stat_arb\data\Kaggle Binance Data\ADA-USDT.parquet")
df_desired
# Out:
#                         open     high      low    close         volume  \
# open_time
# 2018-04-17 04:02:00  0.25551  0.27000  0.25551  0.27000  111061.617188
# 2018-04-17 04:03:00  0.27000  0.27000  0.26100  0.26108   65024.980469
# 2018-04-17 04:04:00  0.26121  0.26729  0.26120  0.26666   92526.726562
# 2018-04-17 04:05:00  0.26700  0.26800  0.26500  0.26666   75961.210938
# 2018-04-17 04:06:00  0.26770  0.26998  0.26700  0.26995  362270.312500
# ...                      ...      ...      ...      ...            ...
# 2022-11-16 23:55:00  0.33240  0.33240  0.33210  0.33220   23097.800781
# 2022-11-16 23:56:00  0.33210  0.33250  0.33200  0.33230   25876.699219
# 2022-11-16 23:57:00  0.33240  0.33250  0.33220  0.33230   82961.101562
# 2022-11-16 23:58:00  0.33230  0.33240  0.33220  0.33230   34555.300781
# 2022-11-16 23:59:00  0.33240  0.33240  0.33200  0.33200  118665.101562
#
#                      quote_asset_volume  number_of_trades  \
# open_time
# ...

# %%
df_desired.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2405947 entries, 2018-04-17 04:02:00 to 2022-11-16 23:59:00
# Data columns (total 9 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   open                          float32
#  1   high                          float32
#  2   low                           float32
#  3   close                         float32
#  4   volume                        float32
#  5   quote_asset_volume            float32
#  6   number_of_trades              uint16
#  7   taker_buy_base_asset_volume   float32
#  8   taker_buy_quote_asset_volume  float32
# dtypes: float32(8), uint16(1)
# memory usage: 96.4 MB
